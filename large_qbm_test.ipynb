# %%
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx

# %%
visible = [i for i in range(36)]
hidden = [36 + j for j in range(8)]
edges = [(i, j) for i in visible for j in hidden]

G = nx.Graph()
G.add_edges_from(edges)
nx.draw_circular(G, with_labels=True, node_color='gold')

# %%
from active_coresets.QBM import QuantumBoltzmannMachine
# Out:
# 2022-02-17 10:37:18.363021: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-02-17 10:37:18.363042: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
base_qbm = QuantumBoltzmannMachine(G, visible, hidden, 2)
data_dist = base_qbm.sample(500)
# Out:
# 2022-02-17 10:37:21.672036: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_UNKNOWN: unknown error
# 2022-02-17 10:37:21.672110: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (jviszlai-XPS-15-9570): /proc/driver/nvidia/version does not exist
# 2022-02-17 10:37:21.674020: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
v_data = data_dist[:,:36]

# %%
qbm = QuantumBoltzmannMachine(G, visible, hidden, 2)
qbm.classical_train(v_data, epochs=1)
# Out:
# Epoch 1/1:
# ....Batch: 1/1
# 2022-02-16 09:37:31.001990: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_UNKNOWN: unknown error
# 2022-02-16 09:37:31.002072: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (jviszlai-XPS-15-9570): /proc/driver/nvidia/version does not exist
# 2022-02-16 09:37:31.002915: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
